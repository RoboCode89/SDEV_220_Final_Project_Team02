# %%
expenses = []
expense1 = {'amount': '$400.00', 'category': 'Groceries'}
expenses.append(expense1)
expense2 = {'amount': '$64.00', 'category': 'Clothes'}
expenses.append(expense2)



def removeExpense(): # The fuction and loop that allows you to remove a expense
    while True:
        listExpenses()
        print("What expense do you want to remove? ")
        try:
            expenseToRemove = int(input("> "))
            del expenses[expenseToRemove]
        except:
            print("Invalid, Please try again")

def addExpense(amount, category): # The function that lets you add a function 
    expense = {'amount': amount, 'category': category}
    expenses.append(expense)


def printMenu(): # lets the user know what their options are 
    print("Please choose from the following options")
    print("1. Add a new Expense")
    print("2. Remove a Expense")
    print("3. List all Expenses")
    
    
def listExpenses(): # This fumction lists the the expenses you have  added and removed 
    print("\nHere are your expenses")
    counter = 0 
    for expense in expenses:
        print("#", counter, " - ", expense['amount'], " - ", expense['category'])
        counter += 1 
    print("\n\n")
    
if __name__ == "__main__":
    while True: 
    ### prints the user 
        printMenu()
        optionSelected = input("> ")
    
    
        if(optionSelected == "1"): # Asking for the user input
            print("How much was this expense?")
            while True:
                try:
                    amountToAdd = input("> ")
                    break
                except: # if entered incorrectly it will ssay invalid pkease try again
                    print("Invalid, Please try again")
                
                
            print("What category was this expense?") # Asking for the user input for the expense category 
            while True:
                try:
                    category = input("> ")
                    break
                except: # if entered incorrectly it will ssay invalid pkease try again
                    print("Invalid, Please try again")
        
            addExpense(amountToAdd, category)
        elif(optionSelected == "2"):
            removeExpense()
        elif(optionSelected == "3"):
            listExpenses()
        else:
            print("Invalid, Please try again")
# Out:
# Please choose from the following options
# 1. Add a new Expense
# 2. Remove a Expense
# 3. List all Expenses
# > 400.00
# Invalid, Please try again
# Please choose from the following options
# 1. Add a new Expense
# 2. Remove a Expense
# 3. List all Expenses
# > 1
# How much was this expense?
# > 400.00
# What category was this expense?
# > clothes
# Please choose from the following options
# 1. Add a new Expense
# 2. Remove a Expense
# 3. List all Expenses
# > 3
#
# Here are your expenses
# # 0  -  $400.00  -  Groceries
# # 1  -  $64.00  -  Jacket
# # 2  -  400.00  -  clothes
#
#
#
# Please choose from the following options
# 1. Add a new Expense
# 2. Remove a Expense
# 3. List all Expenses
# > 2
#
# Here are your expenses
# # 0  -  $400.00  -  Groceries
# # 1  -  $64.00  -  Jacket
# # 2  -  400.00  -  clothes
#
#
#
# What expense do you want to remove?
# > 2
#
# Here are your expenses
# # 0  -  $400.00  -  Groceries
# # 1  -  $64.00  -  Jacket
#
#
#
# ...
